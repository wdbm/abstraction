# %% [markdown]
# # systemdeets

# %%
import datetime

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shijian

# %matplotlib inline
shijian.setup_Jupyter()

# %%
df = pd.read_csv("gpudeets.csv")
df = shijian.add_time_variables(df = df)
df.tail()
# Out:
#                             temperature_C  power_draw_W  utilization_MiB  \
# datetime
# 2018-02-24 16:50:03.215118             91         96.04             2822
# 2018-02-24 16:50:13.247008             91         95.97             2822
# 2018-02-24 16:50:23.289889             91         96.01             2822
# 2018-02-24 16:50:33.321023             91         95.93             2822
# 2018-02-24 16:50:43.350617             91         95.93             2822
#
#                             memory_used_MiB  memory_total_percentage  weekday  \
# datetime
# 2018-02-24 16:50:03.215118             8114                      100        5
# 2018-02-24 16:50:13.247008             8114                      100        5
# 2018-02-24 16:50:23.289889             8114                      100        5
# 2018-02-24 16:50:33.321023             8114                      100        5
# 2018-02-24 16:50:43.350617             8114                      100        5
#
#                            weekday_name time_through_day  \
# datetime
# 2018-02-24 16:50:03.215118     Saturday  16:50:03.215118
# 2018-02-24 16:50:13.247008     Saturday  16:50:13.247008
# 2018-02-24 16:50:23.289889     Saturday  16:50:23.289889
# 2018-02-24 16:50:33.321023     Saturday  16:50:33.321023
# 2018-02-24 16:50:43.350617     Saturday  16:50:43.350617
#
#                             fraction_through_day  hour  hours_through_day  \
# datetime
# 2018-02-24 16:50:03.215118              0.701426    16          16.834226
# 2018-02-24 16:50:13.247008              0.701542    16          16.837013
# 2018-02-24 16:50:23.289889              0.701658    16          16.839803
# 2018-02-24 16:50:33.321023              0.701775    16          16.842589
# 2018-02-24 16:50:43.350617              0.701891    16          16.845375
#
#                             days_through_week  days_through_year
# datetime
# 2018-02-24 16:50:03.215118           5.701426                 55
# 2018-02-24 16:50:13.247008           5.701542                 55
# 2018-02-24 16:50:23.289889           5.701658                 55
# 2018-02-24 16:50:33.321023           5.701775                 55
# 2018-02-24 16:50:43.350617           5.701891                 55

# %% [markdown]
# # temperature

# %%
df.plot(y = ["temperature_C"]);

# %% [markdown]
# # power draw

# %%
df.plot(y = ["power_draw_W"]);

# %% [markdown]
# # histograms

# %%
plt.rcParams["figure.figsize"] = (17, 14)
df[["temperature_C", "power_draw_W"]].hist(bins = 50);
