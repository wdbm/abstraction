# %% [markdown]
# # systemdeets

# %%
import datetime

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shijian

# %matplotlib inline
shijian.setup_Jupyter()

# %%
df = pd.read_csv("gpudeets.csv")
df = shijian.add_time_variables(df = df)
df.tail()
# Out:
#                                              datetime  temperature_C  \
# datetime
# 2018-03-08 14:21:24.041169 2018-03-08 14:21:24.041169             91
# 2018-03-08 14:21:34.085132 2018-03-08 14:21:34.085132             91
# 2018-03-08 14:21:44.127469 2018-03-08 14:21:44.127469             91
# 2018-03-08 14:21:54.155904 2018-03-08 14:21:54.155904             91
# 2018-03-08 14:22:04.192842 2018-03-08 14:22:04.192842             91
#
#                             power_draw_W  utilization_MiB  memory_used_MiB  \
# datetime
# 2018-03-08 14:21:24.041169         94.81             2774             8114
# 2018-03-08 14:21:34.085132         95.20             2774             8114
# 2018-03-08 14:21:44.127469         93.69             2774             8114
# 2018-03-08 14:21:54.155904         95.43             2774             8114
# 2018-03-08 14:22:04.192842         93.65             2774             8114
#
#                             memory_total_percentage  month month_name  \
# datetime
# 2018-03-08 14:21:24.041169                      100      3      March
# 2018-03-08 14:21:34.085132                      100      3      March
# 2018-03-08 14:21:44.127469                      100      3      March
# 2018-03-08 14:21:54.155904                      100      3      March
# 2018-03-08 14:22:04.192842                      100      3      March
#
#                             weekday weekday_name time_through_day  \
# datetime
# 2018-03-08 14:21:24.041169        3     Thursday  14:21:24.041169
# 2018-03-08 14:21:34.085132        3     Thursday  14:21:34.085132
# 2018-03-08 14:21:44.127469        3     Thursday  14:21:44.127469
# 2018-03-08 14:21:54.155904        3     Thursday  14:21:54.155904
# 2018-03-08 14:22:04.192842        3     Thursday  14:22:04.192842
#
#                             fraction_through_day  hour  hours_through_day  \
# datetime
# 2018-03-08 14:21:24.041169              0.598195    14          14.356678
# 2018-03-08 14:21:34.085132              0.598311    14          14.359468
# 2018-03-08 14:21:44.127469              0.598427    14          14.362258
# 2018-03-08 14:21:54.155904              0.598543    14          14.365043
# 2018-03-08 14:22:04.192842              0.598660    14          14.367831
#
#                             days_through_week  days_through_year
# datetime
# 2018-03-08 14:21:24.041169           3.598195                 67
# 2018-03-08 14:21:34.085132           3.598311                 67
# 2018-03-08 14:21:44.127469           3.598427                 67
# 2018-03-08 14:21:54.155904           3.598543                 67
# 2018-03-08 14:22:04.192842           3.598660                 67

# %% [markdown]
# # temperature

# %%
df.plot(y = ["temperature_C"]);

# %% [markdown]
# # power draw

# %%
df.plot(y = ["power_draw_W"]);

# %% [markdown]
# # histograms

# %%
plt.rcParams["figure.figsize"] = (17, 8)
df[["temperature_C", "power_draw_W"]].hist(bins = 50);
